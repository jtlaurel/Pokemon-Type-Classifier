# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers, metrics
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras.models import Model

import os
import matplotlib
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tqdm import tqdm
matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
from skimage import io, color, filters

from PIL import Image
import requests
from io import BytesIO
from imageio import imread

# %%
def process_image(image):
    img = keras.preprocessing.image.load_img(file, target_size=size)
    img_arr = keras.preprocessing.image.img_to_array(img.convert('RGBA'))[:,:,0:3]
    return img_arr/255

# %%
def get_predictions(image, model):
    img = image
    classes = np.array(y_dummies.columns)
    predictions = model.predict(img.reshape(1,256,256,3)
    return predictions

# %%
def get_weakness(type):
    return weaknesses[type]

def get_resistance(type):
    return resistances[type]

def get_immunity(type):
    return immunities[type]

# %%
def get_matchup(type1, type2 = None):
    multipliers  = []
    
    if type2 != None:
        weakness1 = get_weakness(type1)
        resistance1 = get_resistance(type1)
        immunity1 = get_immunity(type1)
        
        weakness2 = get_weakness(type2)
        resistance2 = get_resistance(type2)
        immunity2 = get_immunity(type2)
        
        for index in range(df.shape[0]):
            if str(df['Secondary Type'].loc[index]) != 'nan':
                multiplier1 = 1
                multiplier2 = 1
                if df['Primary Type'].loc[index] in immunity1:
                    multiplier1 *= 0
                    
                elif df['Primary Type'].loc[index] in resistance1:
                    multiplier1 *= 0.5
                    if df ['Primary Type'].loc[index] in immunity2:
                        multiplier1 *= 0
                    elif df['Primary Type'].loc[index] in resistance2:
                        multiplier1 *= 0.5
                    elif df['Primary Type'].loc[index] in weakness2:
                        multiplier1 *= 2
                        
                elif df['Primary Type'].loc[index] in weakness1:
                    multiplier1 *= 2
                    if df ['Primary Type'].loc[index] in immunity2:
                        multiplier1 *= 0
                    elif df['Primary Type'].loc[index] in resistance2:
                        multiplier1 *= 0.5
                    elif df['Primary Type'].loc[index] in weakness2:
                        multiplier1 *= 2
                    
                elif df['Secondary Type'].loc[index] in immunity2:
                    multiplier2 *= 0
                    
                elif df['Secondary Type'].loc[index] in resistance2:
                    multiplier2 *= 0.5
                    if df ['Secondary Type'].loc[index] in immunity1:
                        multiplier2 *= 0
                    elif df['Secondary Type'].loc[index] in resistance1:
                        multiplier2 *= 0.5
                    elif df['Secondary Type'].loc[index] in weakness1:
                        multiplier2 *= 2
                        
                elif df['Secondary Type'].loc[index] in weakness2:
                    multiplier2 *= 2
                    if df ['Secondary Type'].loc[index] in immunity1:
                        multiplier2 *= 0
                    elif df['Secondary Type'].loc[index] in resistance1:
                        multiplier2 *= 0.5
                    elif df['Secondary Type'].loc[index] in weakness1:
                        multiplier2 *= 2
                        
                multipliers.append(max(multiplier1, multiplier2))
                    
            else:
                multiplier1 = 1
                if df['Primary Type'].loc[index] in immunity1:
                    multiplier1 *= 0
                    
                elif df['Primary Type'].loc[index] in resistance1:
                    multiplier1 *= 0.5
                    if df ['Primary Type'].loc[index] in immunity2:
                        multiplier1 *= 0
                    elif df['Primary Type'].loc[index] in resistance2:
                        multiplier1 *= 0.5
                    elif df['Primary Type'].loc[index] in weakness2:
                        multiplier1 *= 2
                        
                elif df['Primary Type'].loc[index] in weakness1:
                    multiplier1 *= 2
                    if df ['Primary Type'].loc[index] in immunity2:
                        multiplier1 *= 0
                    elif df['Primary Type'].loc[index] in resistance2:
                        multiplier1 *= 0.5
                    elif df['Primary Type'].loc[index] in weakness2:
                        multiplier1 *= 2
                        
                multipliers.append(multiplier1)
                
        return multipliers
    
    else:
        weakness1 = get_weakness(type1)
        resistance1 = get_resistance(type1)
        immunity1 = get_immunity(type1)
        
        
        for index in range(df.shape[0]):
            if str(df['Secondary Type'].loc[index]) != 'nan':
                multiplier1 = 1
                multiplier2 = 1
                if df['Primary Type'].loc[index] in immunity1:
                    multiplier1 *= 0
                elif df['Primary Type'].loc[index] in resistance1:
                    multiplier1 *= 0.5
                elif df['Primary Type'].loc[index] in weakness1:
                    multiplier1 *= 2
                elif df['Secondary Type'].loc[index] in immunity1:
                    multiplier2 *= 0
                elif df['Secondary Type'].loc[index] in resistance1:
                    multiplier2 *= 0.5
                elif df['Secondary Type'].loc[index] in weakness1:
                    multiplier2 *= 2
                    
                multipliers.append(max(multiplier1, multiplier2))
            
            else:
                multiplier1 = 1
                if df['Primary Type'].loc[index] in immunity1:
                    multiplier1 *= 0
                elif df['Primary Type'].loc[index] in resistance1:
                    multiplier1 *= 0.5
                elif df['Primary Type'].loc[index] in weakness1:
                    multiplier1 *= 2
                    
                multipliers.append(multiplier1)
                
        return multipliers

# %%
def filter_legendaries(sort_pokemon, legendary, exclude = True):
    if exclude == True:
        return np.array([pokemon for pokemon in sort_pokemon if pokemon not in legendary])
    else: 
        return sort_pokemon

# %%
[pokemon for pokemon in sort_pokemon if pokemon not in legendary]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-820a73134c38> in <module>
# ----> 1 [pokemon for pokemon in sort_pokemon if pokemon not in legendary]
#
# NameError: name 'sort_pokemon' is not defined
